# %%
import pandas as pd
import os

# Load CSV
csv_file = "transcript.csv"
df = pd.read_csv(csv_file)

# Column name you want to extract
column_name = "transcript"

# Output folder
output_dir = "./"
os.makedirs(output_dir, exist_ok=True)

# Create one txt file per row
for index, value in enumerate(df[column_name]):
    file_path = os.path.join(output_dir, f"audio_{index+1}.txt")
    
    with open(file_path, "w", encoding="utf-8") as f:
        f.write(str(value))

print("All text files created successfully!")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[2], line 19
#      16 for index, value in enumerate(df[column_name]):
#      17     file_path = os.path.join(output_dir, f"audio_{index+1}.txt")
# ---> 19     with open(file_path, "w", encoding="utf-8") as f:
#      20         f.write(str(value))
#      22 print("All text files created successfully!")
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: '/audio_1.txt'
